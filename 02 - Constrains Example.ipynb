# %%
# %sql
USE CATALOG dbacademy;
USE SCHEMA default;

# %% [markdown]
# ## SET TABLE CONSTRAINS

# %%
# %sql
CREATE OR REPLACE TABLE customers_delta (
  id BIGINT GENERATED ALWAYS AS IDENTITY,
  customer_id INT NOT NULL,
  name STRING,
  country STRING,
  CONSTRAINT country_allowed CHECK (country IN ('US', 'MX', 'CA'))
);
