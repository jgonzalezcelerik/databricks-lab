# %%
# %sql
USE CATALOG learning_databricks;
USE SCHEMA default;

SELECT current_catalog(), current_schema();

# %%
# %sql
SELECT *
FROM text.`/Volumes/learning_databricks/default/myfiles`;

# %%
# %sql
SELECT *
FROM read_files(
  "/Volumes/learning_databricks/default/jsonfiles",
  format => "json"
)

# %% [markdown]
# ## Create Bronze data from json raw

# %%
# %sql
DROP TABLE IF EXISTS events_bronze_raw;

CREATE TABLE events_bronze_raw AS
SELECT *
FROM read_files(
  "/Volumes/learning_databricks/default/jsonfiles",
  format => "json"
);

SELECT *
FROM events_bronze_raw;
