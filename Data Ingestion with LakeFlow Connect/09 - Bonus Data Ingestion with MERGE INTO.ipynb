# %%
# %sql
USE CATALOG learning_databricks;
USE SCHEMA default;

SELECT current_catalog(), current_schema();

# %%
# %sql
MERGE WITH SCHEMA EVOLUTION INTO target_table target
USING source_table source
ON target.id = source.id
WHEN MATCHED AND source.status = 'update' THEN
  UPDATE SET
    target.email = source.email,
    target.status = source.status
WHEN MATCHED AND source.status = 'delete' THEN
  DELETE
WHEN NOT MATCHED THEN
  INSERT (id, first_name, email, status, country)
  VALUES (source.id, source.firts_name, source.email, source.status, souorce.country)
